# %%
import pandas as pd

# %%
df = pd.read_csv('../data/cleaned/merged_data.csv')
df
# Out:
# /tmp/ipykernel_115766/16763514.py:1: DtypeWarning: Columns (0,24,46,68,89,111,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/cleaned/merged_data.csv')
#        2024-02-06 10:09:00.819065  0.5144752264022827  9.600347518920898  \
# 0      2024-02-06 10:09:00.894707            0.437902           9.648206
# 1      2024-02-06 10:09:00.969533            0.430723           9.664956
# 2      2024-02-06 10:09:01.044500            0.447474           9.609919
# 3      2024-02-06 10:09:01.119285            0.445081           9.547704
# 4      2024-02-06 10:09:01.209678            0.483367           9.650599
# ...                           ...                 ...                ...
# 11508                         NaN                 NaN                NaN
# 11509                         NaN                 NaN                NaN
# 11510                         NaN                 NaN                NaN
# ...

# %%
df.columns
# Out:
# Index(['2024-02-06 10:09:00.819065', '0.5144752264022827', '9.600347518920898',
#        '1.524282455444336', '0', '7.4902e-05', '3.701173826226592e-05',
#        '1.3861266096601208e-09', '0.0007198917698574066',
#        '2.6960666672929734e-08',
#        ...
#        '74.88892089904542', '82.12095972503415', '9.690240411892404',
#        '287.67118409111237', '87.85991974595989', '15.111079100954592',
#        '7.879040274965847', '9.690240411892404.1', '0.0007238680998134586',
#        '2.7066875988224846e-08'],
#       dtype='object', length=155)

# %%
df_processed = pd.read_csv('../data/processed/processed_data1.csv')
df_processed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_processed = pd.read_csv('../data/process/processed_data1.csv')
#       2 df_processed
#
# File ~/gate-matrix-fall-detection/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
